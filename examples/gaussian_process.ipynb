# %%
import sys
sys.path.append("/home/diego/python/stochastic-processes/")

import matplotlib.pyplot as plt
import numpy as np

from processes.gaussian_process import GaussianProcess

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
t = np.arange(0, 200, 1)
gp = GaussianProcess(mu=3, autocov=np.exp(-np.arange(0, 70, 1) / 10)).set_t(t)
x = gp.sample(shape=(4000,))

print(np.mean(x))

plt.plot(np.cov(x)[:, 0]);
plt.plot(np.exp(-np.arange(0, 50, 1) / 10))
# Out:
# 3.004593110170993
